# %% [markdown]
# # Desafío API Rocking Data
# ### Candidato: Miriam Lanabere
# ### Fecha de entrega: 16/07/2021
# ---

# %% [markdown]
# En el marco del proceso de seleccion de RockingData se desarrolla el siguiente desafio:
#
# **Objetivo**
#
# Realizar un análisis sobre la oferta/vidriera de las opciones de productos que responden a
# distintas búsquedas en el sitio Mercadolibre.com.ar
#
# **Consignas**
#
# 1) Barrer una lista de más de 150 ítems ids en el servicio público:
# https://api.mercadolibre.com/sites/MLA/search?q=chromecast&limit=50#json
# En este caso particular y solo a modo de ejemplo, son resultados para la búsqueda
# “chromecast”, pero deberás elegir otros términos para el experimento que permitan
# enriquecer el análisis en un hipotético dashboard (ejemplo Google Home, Apple TV,
# Amazon Fire TV, o afines para poder comparar dispositivos portátiles, o bien elegir
# otros 3 que te interesen para comparar).
#
# 2) Por cada resultado, realizar el correspondiente GET por Item_Id al recurso público:
# https://api.mercadolibre.com/items/{Item_Id}
#
# 3) Escribir los resultados en un archivo plano delimitado por comas, desnormalizando
# el JSON obtenido en el paso anterior, en tantos campos como sea necesario para
# guardar las variables que te interesen modela

# %% [markdown]
# ### Consigna 1

# %% [markdown]
# Para resolver la primer consigna se plantean los siguientes pasos: <br>
# <ul>
#     <li>Importacion de librerias.</li>
#     <li>Armado de función para enviar un request a la URL, almacenar los resultados en una lista y por ultimo transformarlo en un dataframe para poder avanzar luego con la consigna n° 2.</li>
# </ul>

# %%
import time
import requests
import json
import pandas as pd

# %%
url_gh = "https://api.mercadolibre.com/sites/MLA/search?q=Google+Home&limit=50#json" 
url_ap = "https://api.mercadolibre.com/sites/MLA/search?q=Apple+TV&limit=50#json"  
url_am = "https://api.mercadolibre.com/sites/MLA/search?q=Amazon+Fire+TV&limit=50#json"

# %%
def df (url):
    results = []
    response = requests.get(url)
    data = json.loads(response.text)
    results.append(data['results'])
    return results[0]

# %% [markdown]
# **Resultados para la consulta "Google Home"**

# %%
df_gh = pd.DataFrame(df(url_gh))
df_gh.head(2)
# Out:
#              id site_id                                              title  \
# 0  MLA925602267     MLA  Google Home Mini Con Asistente Virtual Google ...
# 1  MLA912827642     MLA  Google Nest Mini 2nd Gen Con Asistente Virtual...
#
#                                               seller   price  \
# 0  {'id': 247639927, 'permalink': 'http://perfil....  6397.0
# 1  {'id': 9198894, 'permalink': 'http://perfil.me...  8350.0
#
#                                               prices sale_price currency_id  \
# 0  {'id': 'MLA925602267', 'prices': [{'id': '31',...       None         ARS
# 1  {'id': 'MLA912827642', 'prices': [{'id': '20',...       None         ARS
#
#    available_quantity  sold_quantity  ... original_price category_id  \
# 0                  28             72  ...            NaN   MLA409415
# 1                  20             11  ...            NaN   MLA409415
#
#   official_store_id           domain_id catalog_product_id  \
# 0              None  MLA-SMART_SPEAKERS        MLA15541915
# 1              None  MLA-SMART_SPEAKERS        MLA15541143
#
#                                                 tags catalog_listing  \
# 0  [good_quality_thumbnail, extended_warranty_eli...            True
# 1  [brand_verified, extended_warranty_eligible, g...            True
#
#    use_thumbnail_id order_backend differential_pricing
# 0              True             1                  NaN
# 1              True             2                  NaN
#
# [2 rows x 33 columns]

# %% [markdown]
# **Resultados para la consulta "Apple TV"**

# %%
df_ap = pd.DataFrame(df(url_ap))
df_ap.head(2)
# Out:
#              id site_id                                              title  \
# 0  MLA913400259     MLA           Apple Tv 4k A1842  De Voz 4k 32gb  Negro
# 1  MLA833896755     MLA   Apple Tv Hd 4th Generation A1625  De Voz Full...
#
#                                               seller    price  \
# 0  {'id': 208137579, 'permalink': 'http://perfil....  37893.0
# 1  {'id': 208137579, 'permalink': 'http://perfil....  37999.0
#
#                                               prices sale_price currency_id  \
# 0  {'id': 'MLA913400259', 'prices': [{'id': '16',...       None         ARS
# 1  {'id': 'MLA833896755', 'prices': [{'id': '26',...       None         ARS
#
#    available_quantity  sold_quantity  ... original_price category_id  \
# 0                   1             72  ...           None   MLA352001
# 1                   1             92  ...           None   MLA352001
#
#   official_store_id                    domain_id catalog_product_id  \
# 0              None  MLA-STREAMING_MEDIA_DEVICES         MLA8972018
# 1              None  MLA-STREAMING_MEDIA_DEVICES         MLA6253544
#
#                                                 tags catalog_listing  \
# 0  [good_quality_picture, good_quality_thumbnail,...            True
# 1  [brand_verified, good_quality_picture, good_qu...            True
#
#    use_thumbnail_id order_backend differential_pricing
# 0              True             1                  NaN
# 1              True             2                  NaN
#
# [2 rows x 33 columns]

# %% [markdown]
# **Resultados para la consulta "Amazon Fire TV"**

# %%
df_am = pd.DataFrame(df(url_am))
df_am.head(2)
# Out:
#              id site_id                                              title  \
# 0  MLA930480651     MLA   Amazon Fire Tv Stick 4k  De Voz 4k 8gb  Negro...
# 1  MLA905217564     MLA   Amazon Fire Tv Stick Lite  De Voz Full Hd 8gb...
#
#                                               seller   price  \
# 0  {'id': 32331880, 'permalink': 'http://perfil.m...  9890.0
# 1  {'id': 153491318, 'permalink': 'http://perfil....  8959.0
#
#                                               prices sale_price currency_id  \
# 0  {'id': 'MLA930480651', 'prices': [{'id': '1', ...       None         ARS
# 1  {'id': 'MLA905217564', 'prices': [{'id': '21',...       None         ARS
#
#    available_quantity  sold_quantity  ... original_price category_id  \
# 0                  18              1  ...            NaN   MLA352001
# 1                 285            326  ...            NaN   MLA352001
#
#   official_store_id                    domain_id catalog_product_id  \
# 0              None  MLA-STREAMING_MEDIA_DEVICES        MLA14141341
# 1              None  MLA-STREAMING_MEDIA_DEVICES        MLA16369065
#
#                                                 tags catalog_listing  \
# 0  [good_quality_picture, good_quality_thumbnail,...            True
# 1  [brand_verified, good_quality_picture, loyalty...            True
#
#    use_thumbnail_id order_backend differential_pricing
# 0              True             1                  NaN
# 1              True             2                  NaN
#
# [2 rows x 33 columns]

# %% [markdown]
# Filtro las columnas según los datos que me interesen para un futuro dashboard comparativo

# %%
df_gh.columns
# Out:
# Index(['id', 'site_id', 'title', 'seller', 'price', 'prices', 'sale_price',
#        'currency_id', 'available_quantity', 'sold_quantity', 'buying_mode',
#        'listing_type_id', 'stop_time', 'condition', 'permalink', 'thumbnail',
#        'thumbnail_id', 'accepts_mercadopago', 'installments', 'address',
#        'shipping', 'seller_address', 'attributes', 'original_price',
#        'category_id', 'official_store_id', 'domain_id', 'catalog_product_id',
#        'tags', 'catalog_listing', 'use_thumbnail_id', 'order_backend',
#        'differential_pricing'],
#       dtype='object')

# %%
# selecciono las columnas que me interesan:

col = ['id', 'title', 'price','currency_id']
df_gh_col = df_gh[col]
df_ap_col = df_ap[col]
df_am_col = df_am[col]
df_gh_col.head()
# Out:
#              id                                              title   price  \
# 0  MLA925602267  Google Home Mini Con Asistente Virtual Google ...  6397.0
# 1  MLA912827642  Google Nest Mini 2nd Gen Con Asistente Virtual...  8350.0
# 2  MLA913417513  Google Home Mini Con Asistente Virtual Google ...  6999.0
# 3  MLA842879853  Google Home Mini Asistete De Voz Y Parlante Bu...  3999.0
# 4  MLA842217261  Google Home Mini Asistete De Voz Y Parlante Mo...  3999.0
#
#   currency_id
# 0         ARS
# 1         ARS
# 2         ARS
# 3         ARS
# 4         ARS

# %% [markdown]
# ### Consigna 2

# %% [markdown]
# Ente paso se realizará lo siguiente: <br>
# <ul>
#     <li>Armar una lista de Items por cada tipo de producto.</li>
#     <li>Armado de función para enviar un request a la URL, almacenar los resultados en una lista, pasarlos a un Data Frame y almacenarlos en una lista.</li>
#     <li>Uno los data frames correspondientes a los items y los concateno con el df de la consigna 1</li>
#     <li>Finalmente limpio el dataset con los datos que me interesan</li>
# </ul>

# %%
item_gh = df_gh['id']
item_ap = df_ap['id']
item_am = df_am['id']

# %%
def df_item (item_list):
    df_list = []
    for item in item_list:
        url_item = f"https://api.mercadolibre.com/items/{item}"
        response = requests.get(url_item)
        data = json.loads(response.text)
        df = pd.DataFrame(data['attributes'])
        df_cut = df[['name', 'value_name']]
        df_cut_transposed = df_cut.set_index('name').transpose()
        df_cut_transposed['id'] = item
        df_list.append(df_cut_transposed)
    return df_list

# %%
#realizo la request por cada item de cada tipo de busqueda

df_item_gh = df_item(item_gh)
df_item_ap = df_item(item_ap)
df_item_am = df_item(item_am)

# %%
#unifico los dataframe

df_item_gh_unique = pd.concat(df_item_gh)
df_item_ap_unique = pd.concat(df_item_ap)
df_item_am_unique = pd.concat(df_item_am)
df_item_gh_unique.head()
# Out:
# name         Marca     Color Diámetro  \
# value_name  Google  Charcoal    98 mm
# value_name  Google     Chalk    98 mm
# value_name  Google     Chalk    98 mm
# value_name  Google       NaN    98 mm
# value_name  Google       NaN    98 mm
#
# name                                                Funciones Altura  \
# value_name  Reproducción de música,Control por voz,Control...  42 mm
# value_name  Reproducción de música,Control por voz,Control...  42 mm
# value_name  Reproducción de música,Control por voz,Control...  42 mm
# value_name  Reproducción de música,Control por voz,Control...  42 mm
# value_name  Reproducción de música,Control por voz,Control...  42 mm
#
# name       Condición del ítem  \
# value_name              Nuevo
# value_name              Nuevo
# value_name              Nuevo
# value_name              Nuevo
# value_name              Nuevo
#
# name                                                  Idiomas  \
# value_name  Inglés Australia,Inglés Canadá,Inglés India,In...
# value_name  Inglés Australia,Inglés Canadá,Inglés India,In...
# value_name  Inglés Australia,Inglés Canadá,Inglés India,In...
# value_name                                     Español,Inglés
# value_name                                     Español,Inglés
#
# name                   Modelo Sistemas operativos compatibles Potencia  ...  \
# value_name          Home Mini            Android 6.0,iOS 12.0      9 W  ...
# value_name  Nest Mini 2nd Gen            Android 6.0,iOS 12.0     15 W  ...
# value_name          Home Mini            Android 6.0,iOS 12.0      9 W  ...
# value_name          Home Mini            Android 6.0,iOS 12.0      9 W  ...
# value_name          Home Mini            Android 6.0,iOS 12.0      9 W  ...
#
# name        Línea           SKU   Tipo de producto Embalaje del envío  \
# value_name    NaN           NaN                NaN                NaN
# value_name   NEST  MLA902472258                NaN                NaN
# value_name  audio           NaN  asistente virtual                NaN
# value_name    NaN           NaN                NaN                NaN
# value_name    NaN           NaN                NaN                NaN
#
# name       Canal exclusivo Profundidad Tamaño de la pantalla Ancho  \
# value_name             NaN         NaN                   NaN   NaN
# value_name             NaN         NaN                   NaN   NaN
# value_name             NaN         NaN                   NaN   NaN
# value_name             NaN         NaN                   NaN   NaN
# value_name             NaN         NaN                   NaN   NaN
#
# name       Con display digital Disponibilidad de stock
# value_name                 NaN                     NaN
# value_name                 NaN                     NaN
# value_name                 NaN                     NaN
# value_name                 NaN                     NaN
# value_name                 NaN                     NaN
#
# [5 rows x 34 columns]

# %%
#uno el df de la consigna 1 con el de la consigna 2

df_full_gh = pd.merge(df_gh_col,df_item_gh_unique, on = 'id')
df_full_ap = pd.merge(df_ap_col,df_item_ap_unique, on = 'id')
df_full_am = pd.merge(df_am_col,df_item_am_unique, on = 'id')
df_full_gh.head()
# Out:
#              id                                              title   price  \
# 0  MLA925602267  Google Home Mini Con Asistente Virtual Google ...  6397.0
# 1  MLA912827642  Google Nest Mini 2nd Gen Con Asistente Virtual...  8350.0
# 2  MLA913417513  Google Home Mini Con Asistente Virtual Google ...  6999.0
# 3  MLA842879853  Google Home Mini Asistete De Voz Y Parlante Bu...  3999.0
# 4  MLA842217261  Google Home Mini Asistete De Voz Y Parlante Mo...  3999.0
#
#   currency_id   Marca     Color Diámetro  \
# 0         ARS  Google  Charcoal    98 mm
# 1         ARS  Google     Chalk    98 mm
# 2         ARS  Google     Chalk    98 mm
# 3         ARS  Google       NaN    98 mm
# 4         ARS  Google       NaN    98 mm
#
#                                            Funciones Altura  \
# 0  Reproducción de música,Control por voz,Control...  42 mm
# 1  Reproducción de música,Control por voz,Control...  42 mm
# 2  Reproducción de música,Control por voz,Control...  42 mm
# 3  Reproducción de música,Control por voz,Control...  42 mm
# 4  Reproducción de música,Control por voz,Control...  42 mm
#
#   Condición del ítem  ...  Línea           SKU   Tipo de producto  \
# 0              Nuevo  ...    NaN           NaN                NaN
# 1              Nuevo  ...   NEST  MLA902472258                NaN
# 2              Nuevo  ...  audio           NaN  asistente virtual
# 3              Nuevo  ...    NaN           NaN                NaN
# 4              Nuevo  ...    NaN           NaN                NaN
#
#   Embalaje del envío Canal exclusivo Profundidad Tamaño de la pantalla Ancho  \
# 0                NaN             NaN         NaN                   NaN   NaN
# 1                NaN             NaN         NaN                   NaN   NaN
# 2                NaN             NaN         NaN                   NaN   NaN
# 3                NaN             NaN         NaN                   NaN   NaN
# 4                NaN             NaN         NaN                   NaN   NaN
#
#   Con display digital Disponibilidad de stock
# 0                 NaN                     NaN
# 1                 NaN                     NaN
# 2                 NaN                     NaN
# 3                 NaN                     NaN
# 4                 NaN                     NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# **Ya tenemos los datasets listos!** <br>
# Ahora los limpiamos para poder guardarlos

# %%
df_full_gh.isnull().sum()
# Out:
# id                                  0
# title                               0
# price                               0
# currency_id                         0
# Marca                               0
# Color                              47
# Diámetro                            2
# Funciones                           2
# Altura                              1
# Condición del ítem                  0
# Idiomas                             2
# Modelo                              0
# Sistemas operativos compatibles     4
# Potencia                            9
# Tipos de alimentación               2
# Frecuencia                          9
# Radiofrecuencia                     6
# Asistentes virtuales                2
# Voltaje                             4
# Peso                                1
# Estándares inalámbricos             6
# Con Bluetooth                       1
# Con cámara                         10
# Con sistema de audio multi-room    12
# Con pantalla táctil                 8
# Con conexión Wi-Fi                  2
# Código universal de producto       40
# Línea                              35
# SKU                                47
# Tipo de producto                   48
# Embalaje del envío                 49
# Canal exclusivo                    49
# Profundidad                        49
# Tamaño de la pantalla              49
# Ancho                              49
# Con display digital                49
# Disponibilidad de stock            47
# dtype: int64

# %%
#eliminamos la columnas con alto porcentaje de nulos

drop_col_gh = ['Color','Código universal de producto', 'Línea', 'SKU', 'Tipo de producto', 'Embalaje del envío', 'Canal exclusivo', \
            'Profundidad', 'Tamaño de la pantalla', 'Ancho', 'Con display digital', 'Disponibilidad de stock' ]

df_full_gh_clean = df_full_gh.drop(columns = drop_col_gh)
df_full_gh_clean.head()
# Out:
#              id                                              title   price  \
# 0  MLA925602267  Google Home Mini Con Asistente Virtual Google ...  6397.0
# 1  MLA912827642  Google Nest Mini 2nd Gen Con Asistente Virtual...  8350.0
# 2  MLA913417513  Google Home Mini Con Asistente Virtual Google ...  6999.0
# 3  MLA842879853  Google Home Mini Asistete De Voz Y Parlante Bu...  3999.0
# 4  MLA842217261  Google Home Mini Asistete De Voz Y Parlante Mo...  3999.0
#
#   currency_id   Marca Diámetro  \
# 0         ARS  Google    98 mm
# 1         ARS  Google    98 mm
# 2         ARS  Google    98 mm
# 3         ARS  Google    98 mm
# 4         ARS  Google    98 mm
#
#                                            Funciones Altura  \
# 0  Reproducción de música,Control por voz,Control...  42 mm
# 1  Reproducción de música,Control por voz,Control...  42 mm
# 2  Reproducción de música,Control por voz,Control...  42 mm
# 3  Reproducción de música,Control por voz,Control...  42 mm
# 4  Reproducción de música,Control por voz,Control...  42 mm
#
#   Condición del ítem                                            Idiomas  ...  \
# 0              Nuevo  Inglés Australia,Inglés Canadá,Inglés India,In...  ...
# 1              Nuevo  Inglés Australia,Inglés Canadá,Inglés India,In...  ...
# 2              Nuevo  Inglés Australia,Inglés Canadá,Inglés India,In...  ...
# 3              Nuevo                                     Español,Inglés  ...
# 4              Nuevo                                     Español,Inglés  ...
#
#   Radiofrecuencia Asistentes virtuales    Voltaje   Peso  \
# 0   2.4 GHz,5 GHz     Google Assistant  110V/220V  173 g
# 1   2.4 GHz,5 GHz     Google Assistant  110V/220V  181 g
# 2   2.4 GHz,5 GHz     Google Assistant  110V/220V  173 g
# 3   2.4 GHz,5 GHz     Google Assistant  110V/220V  173 g
# 4   2.4 GHz,5 GHz     Google Assistant  110V/220V  173 g
#
#   Estándares inalámbricos Con Bluetooth Con cámara  \
# 0     IEEE 802.11b/g/n/ac            Sí         No
# 1   IEEE 802.11a/b/g/n/ac            Sí        NaN
# 2     IEEE 802.11b/g/n/ac            Sí         No
# 3     IEEE 802.11b/g/n/ac            Sí         No
# 4     IEEE 802.11b/g/n/ac            Sí         No
#
#   Con sistema de audio multi-room Con pantalla táctil Con conexión Wi-Fi
# 0                              Sí                  No                 Sí
# 1                             NaN                  No                 Sí
# 2                              Sí                  No                 Sí
# 3                              Sí                  No                 Sí
# 4                              Sí                  No                 Sí
#
# [5 rows x 25 columns]

# %%
df_full_am.isnull().sum()
# Out:
# id                                         0
# title                                      0
# price                                      0
# currency_id                                0
# Interfaces de audio y video                1
# Calidad de audio                           2
# Marca                                      0
# Color                                     44
# Aplicaciones compatibles                   2
# Dispositivos compatibles                   4
# CPU                                        2
# Formato del dispositivo                    2
# Procesador gráfico                         2
# Código universal de producto              34
# Altura                                    15
# Incluye cable HDMI                         6
# Incluye adaptador de corriente             2
# Condición del ítem                         0
# Largo                                      4
# Resolución máxima de video                 0
# Modelo                                     0
# Sistema operativo                          7
# Tipos de puertos y conectores              2
# Memoria RAM                                1
# Tipo de control remoto                     0
# SKU                                       46
# Capacidad de almacenamiento                1
# Ancho                                      4
# Con Bluetooth                              2
# Con Wi-Fi                                  2
# Estándares Wi-Fi                           2
# Línea                                     21
# Sistemas operativos mínimos requeridos    28
# Altura del paquete                        46
# Largo del paquete                         46
# Peso del paquete                          46
# Ancho del paquete                         46
# Tecnología de streaming                   36
# Modelo alfanumérico                       42
# MPN                                       47
# Características del producto              47
# Embalaje del envío                        46
# Canal exclusivo                           44
# Opciones de idioma                        46
# Disponibilidad de stock                   47
# dtype: int64

# %%
#eliminamos la columnas con alto porcentaje de nulos

drop_col_am = ['Color','Código universal de producto', 'SKU', 'Altura del paquete','Largo del paquete', 'Peso del paquete', \
               'Ancho del paquete', 'Tecnología de streaming', 'Modelo alfanumérico', 'MPN','Características del producto', 'Embalaje del envío',\
               'Canal exclusivo', 'Opciones de idioma', 'Disponibilidad de stock' ]

df_full_am_clean = df_full_am.drop(columns = drop_col_am)
df_full_am_clean.head()
# Out:
#              id                                              title    price  \
# 0  MLA930480651   Amazon Fire Tv Stick 4k  De Voz 4k 8gb  Negro...   9890.0
# 1  MLA905217564   Amazon Fire Tv Stick Lite  De Voz Full Hd 8gb...   8959.0
# 2  MLA871126076   Amazon Fire Tv Stick 2nd Generation  De Voz F...   9499.0
# 3  MLA922149816  Amazon Fire Tv Stick 3 Con Alexa Voice Remote ...  21990.0
# 4  MLA913465738   Amazon Fire Tv Cube 2nd Generation  De Voz 4k...  49400.0
#
#   currency_id Interfaces de audio y video  \
# 0         ARS                        HDMI
# 1         ARS                        HDMI
# 2         ARS                        HDMI
# 3         ARS                        HDMI
# 4         ARS                        HDMI
#
#                                Calidad de audio   Marca  \
# 0    Dolby Digital Plus,Wave,Vorbis,Dolby Atmos  Amazon
# 1  Dolby Digital,Dolby Digital Plus,Dolby Atmos  Amazon
# 2                Dolby Digital Plus,Dolby Audio  Amazon
# 3  Dolby Digital Plus,Dolby Atmos,Dolby Digital  Amazon
# 4  Dolby Atmos,Dolby Digital,Dolby Digital Plus  Amazon
#
#                             Aplicaciones compatibles  \
# 0  Netflix,YouTube,Amazon Prime Video,Starz,Showt...
# 1  Netflix,Amazon Prime Video,YouTube,Atresplayer...
# 2  YouTube,Pluto TV,Tubi,SonyCrackle,IMDb TV,Amaz...
# 3           Netflix,YouTube,flow,Spotify,Prime Video
# 4  HBO,Hulu,Showtime,Netflix,Amazon Prime Video,S...
#
#                     Dispositivos compatibles                       CPU  ...  \
# 0                                Televisores  ARM Cortex-A53 Quad-Core  ...
# 1                                Televisores             ARM Quad-Core  ...
# 2                      Televisores,Celulares   ARM Cortex-A7 Quad-Core  ...
# 3                                Televisores                 Quad-Core  ...
# 4  Televisores,Auriculares,Gamepad,Parlantes   Amlogic S922X Hexa-Core  ...
#
#    Tipos de puertos y conectores Memoria RAM Tipo de control remoto  \
# 0                      Micro USB      1.5 GB                 De voz
# 1                      Micro USB        1 GB                 De voz
# 2                      Micro USB        1 GB                 De voz
# 3                      Micro USB        1 GB                 De voz
# 4  DC jack,Micro USB,IR,Ethernet        2 GB                 De voz
#
#   Capacidad de almacenamiento    Ancho Con Bluetooth Con Wi-Fi  \
# 0                        8 GB    14 mm            Sí        Sí
# 1                        8 GB    30 mm            Sí        Sí
# 2                        8 GB    1.8 "            Sí        Sí
# 3                        8 GB      NaN            Sí        Sí
# 4                       16 GB  86.1 mm            Sí        Sí
#
#   Estándares Wi-Fi      Línea Sistemas operativos mínimos requeridos
# 0      2.4GHz,5GHz        NaN                                    NaN
# 1      5GHz,2.4GHz    Fire TV                            Android,iOS
# 2      5GHz,2.4GHz        NaN                                    NaN
# 3      2.4GHz,5GHz        NaN                                Android
# 4      2.4GHz,5GHz  Tv Stream                        Fire OS,Android
#
# [5 rows x 30 columns]

# %%
df_full_ap.isnull().sum()
# Out:
# id                                         0
# title                                      0
# price                                      0
# currency_id                                0
# Modelo alfanumérico                        6
# Interfaces de audio y video               14
# Calidad de audio                          24
# Marca                                      0
# Color                                     45
# Aplicaciones compatibles                  22
# Dispositivos compatibles                  16
# CPU                                       17
# Formato del dispositivo                   13
# Procesador gráfico                        40
# Código universal de producto              40
# Altura                                    17
# Incluye adaptador de corriente            22
# Condición del ítem                         0
# Largo                                     18
# Línea                                     15
# Resolución máxima de video                14
# Sistemas operativos mínimos requeridos    43
# Modelo                                     0
# MPN                                       46
# Sistema operativo                         34
# Altura del paquete                        46
# Largo del paquete                         46
# Peso del paquete                          46
# Ancho del paquete                         46
# Tipos de puertos y conectores             18
# Memoria RAM                               21
# Tipo de control remoto                    11
# SKU                                       43
# Capacidad de almacenamiento               12
# Tecnología de streaming                   20
# Ancho                                     18
# Con Bluetooth                             17
# Con Wi-Fi                                 15
# Estándares Wi-Fi                          31
# Características del producto              44
# Embalaje del envío                        44
# Incluye cable HDMI                        40
# Voltaje de funcionamiento                 47
# Es kit                                    47
# Opciones de idioma                        46
# Fuente del producto                       47
# Información adicional requerida           46
# Características de las baterías           46
# Disponibilidad de stock                   44
# Canal exclusivo                           47
# dtype: int64

# %%
#eliminamos la columnas con alto porcentaje de nulos

drop_col_ap = ['Color','Procesador gráfico','Código universal de producto', 'Sistemas operativos mínimos requeridos','MPN',\
               'Altura del paquete','Largo del paquete', 'Peso del paquete', 'Ancho del paquete' ,'SKU', 'Características del producto', \
               'Embalaje del envío','Incluye cable HDMI','Voltaje de funcionamiento', 'Es kit', 'Opciones de idioma','Fuente del producto', \
               'Información adicional requerida', 'Características de las baterías', 'Canal exclusivo',  'Disponibilidad de stock' ]

df_full_ap_clean = df_full_ap.drop(columns = drop_col_ap)
df_full_ap_clean.head()
# Out:
#              id                                              title    price  \
# 0  MLA913400259           Apple Tv 4k A1842  De Voz 4k 32gb  Negro  37893.0
# 1  MLA833896755   Apple Tv Hd 4th Generation A1625  De Voz Full...  37999.0
# 2  MLA908889816       Soporte Para Apple Tv Todas Las Generaciones    399.0
# 3  MLA810728897                        Apple Tv 32 Gb 4 Generación  37999.0
# 4  MLA879232016          Soporte Para Apple Tv Decodificadores Tgw   1100.0
#
#   currency_id Modelo alfanumérico Interfaces de audio y video  \
# 0         ARS               A1842                        HDMI
# 1         ARS               A1625                        HDMI
# 2         ARS                   1                        None
# 3         ARS               A1625                        HDMI
# 4         ARS       7798141769506                        None
#
#                                Calidad de audio  Marca  \
# 0  Dolby Digital Plus,Dolby Digital,Dolby Atmos  Apple
# 1      Dolby Digital 5.1,Dolby Digital Plus 7.1  Apple
# 2                                           NaN  Apple
# 3      Dolby Digital 5.1,Dolby Digital Plus 7.1  Apple
# 4                                           NaN  Apple
#
#                             Aplicaciones compatibles  \
# 0  Netflix,Hulu,MLB.TV,HBO Now,Bloomberg TV,CNN,N...
# 1        iTunes,Amazon Prime Video,ESPN,Hulu,Netflix
# 2                                                NaN
# 3                                  App Store, iTunes
# 4                                                NaN
#
#                      Dispositivos compatibles  ... Sistema operativo  \
# 0  Televisores,Celulares,Tablets,Computadoras  ...           tvOS 11
# 1          Televisores,Teclado,Celulares,iPad  ...               NaN
# 2                                         NaN  ...               NaN
# 3                        Televisores con HDMI  ...          tvOS 9.0
# 4                                         NaN  ...               NaN
#
#               Tipos de puertos y conectores Memoria RAM  \
# 0            Apple power supply,Ethernet,IR        3 GB
# 1      Apple power supply,USB-C,Ethernet,IR        2 GB
# 2                                       NaN        1 GB
# 3  Apple power supply, USB tipo-C, Ethernet        2 GB
# 4                                       NaN        None
#
#   Tipo de control remoto Capacidad de almacenamiento Tecnología de streaming  \
# 0                 De voz                       32 GB                 AirPlay
# 1                 De voz                       32 GB                 AirPlay
# 2                   None                        1 GB                     NaN
# 3                 De voz                       32 GB                Miracast
# 4                   None                        None                     NaN
#
#    Ancho Con Bluetooth Con Wi-Fi Estándares Wi-Fi
# 0  98 mm            Sí        Sí      2.4GHz,5GHz
# 1  98 mm            Sí        Sí              NaN
# 2    NaN           NaN       NaN              NaN
# 3  98 mm            Sí        Sí              NaN
# 4    NaN           NaN       NaN              NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Consigna 3
#
# Exportamos el resultado a un CSV

# %%
df_full_gh_clean.to_csv('../RockingData/googleHome.csv', index=False)
df_full_ap_clean.to_csv('../RockingData/appleTv.csv', index=False)
df_full_am_clean.to_csv('../RockingData/amazonFireTv.csv', index=False)
